# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = np.loadtxt("54.dat")
x = linspace(0,1,1000)

print datos
# Out:
# [  3.30000000e-05   6.50000000e-05   9.80000000e-05   1.30000000e-04
#    1.66000000e-04   1.95000000e-04   2.35000000e-04   2.64000000e-04
#    3.03000000e-04   3.39000000e-04   3.70000000e-04   4.18000000e-04
#    4.47000000e-04   4.88000000e-04   5.39000000e-04   5.67000000e-04
#    6.13000000e-04   6.72000000e-04   7.05000000e-04   7.42000000e-04
#    8.11000000e-04   8.74000000e-04   9.05000000e-04   9.36000000e-04
#    1.00200000e-03   1.10000000e-03   1.20500000e-03   1.30200000e-03
#    1.38600000e-03   1.46400000e-03   1.54100000e-03   1.61900000e-03
#    1.69900000e-03   1.78400000e-03   1.87200000e-03   1.96400000e-03
#    2.06000000e-03   2.16000000e-03   2.26500000e-03   2.37400000e-03
#    2.48900000e-03   2.60800000e-03   2.73200000e-03   2.86200000e-03
#    2.99700000e-03   3.13900000e-03   3.28600000e-03   3.43900000e-03
#    3.59900000e-03   3.76600000e-03   3.94000000e-03   4.12000000e-03
#    4.30900000e-03   4.50500000e-03   4.70900000e-03   4.92100000e-03
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-7fd244c689d2> in <module>()
# ----> 1 plot(datos[:,0],datos[:,1])
#       2 plot(datos[:,0],datos[:,2])
#       3 plt.xlabel('x')
#       4 plt.ylabel('u')
#
# IndexError: invalid index
